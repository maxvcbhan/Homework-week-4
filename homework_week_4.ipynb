# %% [markdown]
# <a href="https://colab.research.google.com/github/maxvcbhan/Homework-week-4/blob/main/homework_week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/ML/smartphone-reponse.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 12 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Timestamp                                                        75 non-null     object
#  1   เพศของผู้ตอบแบบสอบถาม                                            75 non-null     object
#  2   ช่วงอายุของผู้ตอบแบบสอบถาม                                       75 non-null     object
#  3   อาชีพของผู้ตอบแบบสอบถาม                                          75 non-null     object
#  4   ช่วงเงินเดือนของผู้ตอบแบบสอบถาม                                  75 non-null     object
#  5   ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด                         75 non-null     object
#  6   ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]                   75 non-null     object
# ...

# %%
columns=['เพศของผู้ตอบแบบสอบถาม','อาชีพของผู้ตอบแบบสอบถาม', 'ช่วงอายุของผู้ตอบแบบสอบถาม','ช่วงเงินเดือนของผู้ตอบแบบสอบถาม', 'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]' ,'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]','ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]','ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]','หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด']
# column_mapping = {
#     "เพศของผู้ตอบแบบสอบถาม": "Gender",
#     "ช่วงอายุของผู้ตอบแบบสอบถาม": "Age Group",
#     "อาชีพของผู้ตอบแบบสอบถาม": "Occupation",
#     "ช่วงเงินเดือนของผู้ตอบแบบสอบถาม": "Salary",
#     "ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด": "Current Smartphone OS",
#     "ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]": "Smartphone Usage [Gaming]",
#     "ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]": "Smartphone Usage [Social Media]",
#     "ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]": "Smartphone Usage [Movies/Music]",
#     "ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]": "Smartphone Usage [Photo/Video]",
#     "หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด": "New Smartphone Brand",
#     "จากข้อที่แล้ว เนื่องจากสาเหตุใด": "Reason for Smartphone Choice"
# }

# Rename the columns in the DataFrame
# df_cleaned_renamed = df.rename(columns=column_mapping)
df_encoded = df[df["จากข้อที่แล้ว เนื่องจากสาเหตุใด"] != "IOS และ Andriod"]
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 12 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Timestamp                                                        75 non-null     object
#  1   เพศของผู้ตอบแบบสอบถาม                                            75 non-null     object
#  2   ช่วงอายุของผู้ตอบแบบสอบถาม                                       75 non-null     object
#  3   อาชีพของผู้ตอบแบบสอบถาม                                          75 non-null     object
#  4   ช่วงเงินเดือนของผู้ตอบแบบสอบถาม                                  75 non-null     object
#  5   ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด                         75 non-null     object
#  6   ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]                   75 non-null     object
# ...

# %%
colums_to_remove = ['Timestamp','จากข้อที่แล้ว เนื่องจากสาเหตุใด']
df_encoded = df_encoded.drop(columns=colums_to_remove, axis=1)
df_encoded
# Out:
#    เพศของผู้ตอบแบบสอบถาม ช่วงอายุของผู้ตอบแบบสอบถาม อาชีพของผู้ตอบแบบสอบถาม  \
# 0                    ชาย                   26-30 ปี                   เอกชน
# 1                   หญิง                   21-25 ปี                   เอกชน
# 2                    ชาย                   26-30 ปี                   เอกชน
# 3                    ชาย                   31-35 ปี                   เอกชน
# 4                    ชาย                   21-25 ปี                   เอกชน
# ..                   ...                        ...                     ...
# 70                  หญิง                   26-30 ปี                   เอกชน
# 71                   ชาย                   31-35 ปี                   เอกชน
# 72                  หญิง                   21-25 ปี                นักศึกษา
# 73                   ชาย                   26-30 ปี                   เอกชน
# 74                   ชาย                   31-35 ปี               ข้าราชการ
#
# ...

# %%
columns = df_encoded.columns.tolist()
columns
# Out:
# ['เพศของผู้ตอบแบบสอบถาม',
#  'ช่วงอายุของผู้ตอบแบบสอบถาม',
#  'อาชีพของผู้ตอบแบบสอบถาม',
#  'ช่วงเงินเดือนของผู้ตอบแบบสอบถาม',
#  'ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด',
#  'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]',
#  'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]',
#  'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]',
#  'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]',
#  'หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด']

# %%
columns = ['เพศของผู้ตอบแบบสอบถาม',
 'ช่วงอายุของผู้ตอบแบบสอบถาม',
 'อาชีพของผู้ตอบแบบสอบถาม',
 'ช่วงเงินเดือนของผู้ตอบแบบสอบถาม',
 'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]',
 'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]',
 'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]',
 'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]',
 'หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด']
df_encoded = pd.get_dummies(df_encoded, columns=columns)
df_encoded
# Out:
#    ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด  เพศของผู้ตอบแบบสอบถาม_-  \
# 0                           IOS และ Andriod                    False
# 1                                       IOS                    False
# 2                                       IOS                    False
# 3                                       IOS                    False
# 4                                       IOS                    False
# ..                                      ...                      ...
# 70                                  Android                    False
# 71                                      IOS                    False
# 72                                  Android                    False
# 73                                      IOS                    False
# 74                                  Android                    False
#
#     เพศของผู้ตอบแบบสอบถาม_ชาย  เพศของผู้ตอบแบบสอบถาม_หญิง  \
# 0                        True                       False
# ...

# %%
df_encoded = df_encoded[ df_encoded["ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด"] != "IOS และ Andriod" ]
df_encoded
# Out:
#    ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด  เพศของผู้ตอบแบบสอบถาม_-  \
# 1                                       IOS                    False
# 2                                       IOS                    False
# 3                                       IOS                    False
# 4                                       IOS                    False
# 5                                       IOS                    False
# ..                                      ...                      ...
# 70                                  Android                    False
# 71                                      IOS                    False
# 72                                  Android                    False
# 73                                      IOS                    False
# 74                                  Android                    False
#
#     เพศของผู้ตอบแบบสอบถาม_ชาย  เพศของผู้ตอบแบบสอบถาม_หญิง  \
# 1                       False                        True
# ...

# %%
df_encoded["ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด"] = df_encoded["ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด"].replace({"IOS": 1, 'Android': 0})
df_encoded
# Out:
# <ipython-input-47-bdedfc42973b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded["ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด"] = df_encoded["ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด"].replace({"IOS": 1, 'Android': 0})
#     ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด  เพศของผู้ตอบแบบสอบถาม_-  \
# 1                                          1                    False
# 2                                          1                    False
# 3                                          1                    False
# 4                                          1                    False
# 5                                          1                    False
# ..                                       ...                      ...
# ...

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71 entries, 1 to 74
# Data columns (total 49 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด                                   71 non-null     int64
#  1   เพศของผู้ตอบแบบสอบถาม_-                                                    71 non-null     bool
#  2   เพศของผู้ตอบแบบสอบถาม_ชาย                                                  71 non-null     bool
#  3   เพศของผู้ตอบแบบสอบถาม_หญิง                                                 71 non-null     bool
#  4   ช่วงอายุของผู้ตอบแบบสอบถาม_21-25 ปี                                        71 non-null     bool
#  5   ช่วงอายุของผู้ตอบแบบสอบถาม_26-30 ปี                                        71 non-null     bool
# ...

# %%
df_encoded  = df_encoded.replace({True: 1, False: 0})
df_encoded
# Out:
#     ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด  เพศของผู้ตอบแบบสอบถาม_-  \
# 1                                          1                        0
# 2                                          1                        0
# 3                                          1                        0
# 4                                          1                        0
# 5                                          1                        0
# ..                                       ...                      ...
# 70                                         0                        0
# 71                                         1                        0
# 72                                         0                        0
# 73                                         1                        0
# 74                                         0                        0
#
#     เพศของผู้ตอบแบบสอบถาม_ชาย  เพศของผู้ตอบแบบสอบถาม_หญิง  \
# 1                           0                           1
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Select features (X) and target (y)
X = df_encoded.drop('ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด', axis=1)
y = df_encoded['ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด']

y
# Out:
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
#      ..
# 70    0
# 71    1
# 72    0
# 73    1
# 74    0
# Name: ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด, Length: 71, dtype: int64

# %%
# Split the dataset into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

# Create a logistic regression model
logistic_model = LogisticRegression()

# Train the model
logistic_model.fit(X_train, y_train)

# Test the model
accuracy = logistic_model.score(X_test, y_test)

accuracy
# Out:
# 0.8181818181818182

# %%
# !pip install shap

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# !wget -q https://github.com/google/fonts/raw/main/ofl/sarabun/Sarabun-Regular.ttf
mpl.font_manager.fontManager.addfont('Sarabun-Regular.ttf')
mpl.rc('font', family='Sarabun')
plt.rcParams ['font.family'] = ('Sarabun')

# %%
import shap
from sklearn.metrics import classification_report

print(classification_report(y_test, logistic_model.predict(X_test)))

# explain all the predictions in the test set
# explainer = shap.KernelExplainer(.predict_proba, X_train)
# shap_values = explainer.shap_values(X_test)
# shap.force_plot(explainer.expected_value[0], shap_values[..., 0], X_test)
# explainer = shap.Explainer(logistic_model, X_train)
# explainer = shap.KernelExplainer(logistic_model.predict_proba, X_train)
# shap_values = explainer.shap_values(X_test)
explainer = shap.Explainer(logistic_model, X_train, feature_names=df_encoded.columns.tolist())
shap_values = explainer(X_test)

# explainer = shap.Explainer(logistic_model, X_train)
# shap_values = explainer(X_test)

# explainer = shap.LinearExplainer(logistic_model, X_train)
# shap_values = explainer.shap_values(X_test)
# # Calculate SHAP values for the test set
# shap_values = explainer(X_test)
# shap_values = explainer(X_test)
# Visualize the SHAP values with a beeswarm plot
shap.plots.initjs()
shap.plots.beeswarm(shap_values)
shap.plots
# shap_values
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.82      1.00      0.90        18
#
#     accuracy                           0.82        22
#    macro avg       0.41      0.50      0.45        22
# weighted avg       0.67      0.82      0.74        22
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
